# %% [markdown]
# <a href="https://colab.research.google.com/github/venusinfire/SenalesySistemas2023-2/blob/main/IntroduccionSyS/Copia_de_Operaciones_de_se%C3%B1ales_continuas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Operaciones básicas sobre señales
#
# Las operaciones como la superposición, el cambio temporal y el escalamiento, se utilizan para construir señales con una estructura más compleja.
#
# Se introduce un conjunto de operaciones elementales que se utilizan frecuentemente en el procesamiento de señales.

# %% [markdown]
# ### Superposición
#
# La superposición $x(t)$ de dos señales $x_1(t)$ and $x_2(t)$ está dada por:
#
# \begin{equation}
# x(t) = A \cdot x_1(t) + B \cdot x_2(t)
# \end{equation}
#
# con los pesos complejos $A, B \in \mathbb{C}$.

# %% [markdown]
# **Ejemplo**
#
# El siguiente ejemplo ilustra la superposición de dos señales armónicas $x(t) = A \cdot \cos(\omega_1 t) + B \cdot \cos(\omega_2 t)$ con pesos $A$, $B$ y frecuencia angular $\omega_1$ y $\omega_2$.

# %%
# %matplotlib inline
import sympy as sym

t = sym.symbols('t', real=True)#se declara la variable simbólica t

#parámetros de las funciones cos
A = .3
om1 = 3
B = .5
om2 = 5

#operación superposición en sympy
x = A*sym.cos(om1*t) + B*sym.cos(om2*t)
#se grafica la señal resultante
sym.plot(x, (t,-5,5), ylim=[-1.2, 1.2], ylabel=r'$x(t)$');

# %% [markdown]
# ### Desplazamiento temporal
#
# El desplazamiento temporal de una señal $s(t)$ en un instante de tiempo $\tau$ es una operación frecuentemente aplicada en el procesamiento de señales. Por ejemplo, para modelar la propagación de señales desde un actuador a un sensor.
#
# El desplazamiento de la señal $x(t)$ está definido como:
#
# \begin{equation}
# x(t) = s(t-\tau)
# \end{equation}
#
# con $\tau \in \mathbb{R}$. La señal $s(t)$ es:
#
# * desplazada hacia la derecha (*retrasada*) para $\tau > 0$
# * desplazada hacia la izquierda para $\tau < 0$

# %% [markdown]
# **Ejemplo**
#
# Para ilustrar el cambio temporal de señales, la construcción de una señal escalera por una superposición de desplazamiento se define como:
#
# \begin{equation}
# x(t) = \text{rect}\left(t - \frac{1}{2} \right) + \frac{2}{3} \cdot \text{rect}\left(t-\frac{3}{2} \right) + \frac{1}{3} \cdot \text{rect} \left(t-\frac{5}{2} \right)
# \end{equation}

# %%
rect = sym.Heaviside(t + 0.5) - sym.Heaviside(t - 0.5)
sym.plot(rect, xlim=[-2,2], ylabel = r'rect(t)')
#los rect desplazados se acoplan con escalamientos diferentes
x = rect.subs(t, t-1/2) + 2/3*rect.subs(t, t-3/2) + 1/3*rect.subs(t, t-5/2)
sym.plot(x, (t, -1, 5), ylim=[-0.2, 1.2], ylabel='$x(t)$');

# %% [markdown]
# **Ejercicio**
#
# * Agregar otro escalón al principio de la señal escalera modificando el ejemplo anterior.
#
# Para agregar otro escalón al principio de la señal escalera, simplemente necesitamos agregar otro término a la ecuación.
# Para agregar un escalón al principio a la señal le sumamos un nuevo pulso rectangular con centro en $-\frac{1}{2}$ y de amplitud $\frac{4}{3}$ para seguir el patrón de la escalera.
#
#
# \begin{equation}
# x(t) = \frac{4}{3} \cdot \text{rect}\left(t + \frac{1}{2}\right) + \text{rect}\left(t - \frac{1}{2}\right) + \frac{2}{3} \cdot \text{rect}\left(t-\frac{3}{2}\right) + \frac{1}{3} \cdot \text{rect} \left(t-\frac{5}{2}\right)
# \end{equation}
#
#
#
#
#
#
#
# Como se mira en la gráfica, al sumar este nuevo pulso rectangular se agrega un escalón al inicio de la escalera.

# %%
# Definición de la función rect (pulso rectangular) utilizando Heaviside
rect = sym.Heaviside(t + 0.5) - sym.Heaviside(t - 0.5)

# Graficar la función rect en el rango de -2 a 2
sym.plot(rect, xlim=[-2,2], ylabel = r'rect(t)')

# Crear una nueva función x(t) que es una superposición de pulsos rectangulares
# Se agrega un nuevo pulso rectangular con centro en -1/2 y amplitud 4/3 a la función original
x = 4/3*rect.subs(t, t+1/2) + rect.subs(t, t-1/2) + 2/3*rect.subs(t, t-3/2) + 1/3*rect.subs(t, t-5/2)

# Graficar la función x(t) en el rango de -2 a 5
sym.plot(x, (t, -2, 5), ylim=[-0.2, 1.5], ylabel='$x(t)$')

# %% [markdown]
# ### Escalamiento temporal
#
# El escalamiento temporal de una señal $s(t)$ está definido como:
#
# \begin{equation}
# x(t) = s(a \cdot t)
# \end{equation}
#
# con $a \in \mathbb{R}$. La señal $s(t)$ es
#
# * estirada para $0 < a < 1$
# * comprimida $a > 1$
# * invertida y escalada para $a < 0$
#
# Una aplicación de escalado temporal en el procesamiento de la señal es la escala de las señales estándar y el modelado del [efecto Doppler](https://en.wikipedia.org/wiki/Doppler_effect).

# %% [markdown]
# **Ejemplo**
#
# El siguiente ejemplo ilustra el escalamiento de una señal escalera $y(t) = x(a \cdot t)$.

# %%
a = sym.symbols('a', real=True)
y = x.subs(t, a*t)

px = sym.plot(x, (t, -7, 7), ylim=[-0.2, 1.2], ylabel=r'$y(t)$', show=False, line_color='gray')
py = sym.plot(y.subs(a,1/2), (t, -7, 7), ylim=[-0.2, 1.2], ylabel=r'$y(t)$', show=False)
px.extend(py)#se extiende los gráficos sobre una misma figura
px.show()

# %% [markdown]
# **Ejercicio**
#
# * Modifique el ejemplo anterior para que la señal se comprima.
# * Modifique el ejemplo anterior para que la señal se escale y se invierta. ¿Qué factor de escala `a`da como resultado un       estiramiento/compresión en este contexto?

# %% [markdown]
# Para comprimir una señal, el escalamiento debe ser $a > 1$:
#
# $a = \frac{4}{3}$
#
# Para estirar una señal, el escalamiento debe ser $0 < a < 1$:
#
# $a = -\frac{6}{3}$
#
# Para invertir una señal, el escalamiento debe ser $a < 0$:
#
# $a = -\frac{1}{2}$
#
# Para las señales invertidas, el estiramiento o compresión de la señal cumple las mismas características de ser mayor o menor que 0 o 1.

# %%
# Señal comprimida
px1 = sym.plot(x, (t, -7, 7), ylim=[-0.5, 3], ylabel=r'$y(t)$', show=False, line_color='gray')
py1 = sym.plot(y.subs(a,4/3), (t, -7, 7), ylim=[-0.5, 3], ylabel=r'$y(t)$', show=False)
px1.extend(py1)#se extiende los gráficos sobre una misma figura
px1.show()

# %%
# Señal comprimida e invertida
px2 = sym.plot(x, (t, -7, 7), ylim=[-0.2, 3], ylabel=r'$y(t)$', show=False, line_color='gray')
py2 = sym.plot(y.subs(a,-6/3), (t, -7, 7), ylim=[-0.2, 3], ylabel=r'$y(t)$', show=False)
px2.extend(py2)#se extiende los gráficos sobre una misma figura
px2.show()

# %%
# Señal estirada e invertida
px3 = sym.plot(x, (t, -7, 7), ylim=[-0.2, 3], ylabel=r'$y(t)$', show=False, line_color='gray')
py3 = sym.plot(y.subs(a, -1/2), (t, -7, 7), ylim=[-0.2, 3], ylabel=r'$y(t)$', show=False)
px3.extend(py3)
px3.show()

# %% [markdown]
# ### Desplazamiento Temporal

# %% [markdown]
# El desplazamiento temporal de una señal $s(t)$ está definido como
#
# \begin{equation}
# x(t) = s(\tau - t)
# \end{equation}
#
# para $\tau \in \mathbb{R}$. Como $s(\tau - t) = s(- (t - \tau))$ la operación espejo también se puede representar como una inversión temporal de la señal $s(t)$ seguida por un desplazamiento de $\tau$ de la señal invertida. Para $\tau = 0$ este resultado es solo una inversión temporal de la señal.
#
# La operación de cambio temporal puede interpretarse geométricamente como un reflejo de la señal $s(t)$ en el eje vertical $t=\frac{\tau}{2}$.

# %% [markdown]
# **Ejemplo**
#
# El siguiente ejemplo ilustra el cambio temporal $y(t) = x(\tau - t)$ de la señal escalera $x(t)$ anteriormente introducida.

# %%
tau =-1
y = x.subs(t, tau - t)

px=sym.plot(x, (t, -7, 7), ylim=[-0.2, 1.2], ylabel=r'$y(t)$', line_color='gray', show=False)
py=sym.plot(y, (t, -7, 7), ylim=[-0.2, 1.2], ylabel=r'$y(t)$', show=False)
px.extend(py)
px.show()

# %% [markdown]
# **Ejercicio**
#
# * Para que valor de $\tau$, ¿la señal comienza en $t=0$?
# * Realice un cambio temporal dividiendo en dos operaciones consecutivas: (i) Inversión temporal y (ii) Desplazamiento temporal.

# %%
tau = 0
y = x.subs(t, tau-t)

py = sym.plot(y, (t, -7, 7), ylim=[-0.2, 2], show=False)
py.show()

# %% [markdown]
# Imaginando una función escalera denotada como $x(t)$. Si esta función se desplaza en el tiempo en un valor $\tau = 2$ segundos y luego se invierte, podemos describir este proceso de dos maneras equivalentes.
#
# En primer lugar, podemos expresarlo como una inversión temporal directa, lo que significa que cambiamos el signo del tiempo en la función original:
#
# \begin{equation}
# x(-(t-\tau))=x(\tau-t)=x(2-t)
# \end{equation}
#
# En segundo lugar, podemos dividir este proceso en dos pasos consecutivos. Primero, realizamos una inversión temporal, lo que equivale a multiplicar la función por $-1$ en el dominio del tiempo ($x(t) \rightarrow x(-1 \cdot t)$). Luego, aplicamos un desplazamiento temporal de $\tau$ segundos hacia la derecha, lo que se representa como $x(-t+\tau)$. Ambos pasos juntos resultan en el mismo efecto que la inversión seguida de un desplazamiento temporal:
#
# \begin{equation}
# x(t) \rightarrow x(-1 \cdot t) \rightarrow x(-t+\tau) \rightarrow x(\tau-t)
# \end{equation}

# %%
# Definición de la función x con tres funciones escalón combinadas
x = rect.subs(t, a*t-1/2) + 2/3*rect.subs(t, a*t-3/2) + 1/3*rect.subs(t, a*t-5/2)


p1 = sym.plot(x.subs(a, 1), (t, -7, 7), ylim=[-0.2, 1.2], show=False)
x1 = x.subs(a, -1)
p2 = sym.plot(x1, (t, -7, 7), ylim=[-0.2, 2], show=False)
p2.extend(p1)
tau = 2

# Creación de una nueva función x2 desplazada en el tiempo
x2 = x1.subs(t, tau+t)
p3 = sym.plot(x2, (t, -7, 7), ylim=[-0.2, 2], show=False)
p3.extend(p2)
p3.show()

# %% [markdown]
# **Copyright**
#
# The notebook is provided as [Open Educational Resource](https://de.wikipedia.org/wiki/Open_Educational_Resources). Feel free to use the notebook for your own educational purposes. The text is licensed under [Creative Commons Attribution 4.0](https://creativecommons.org/licenses/by/4.0/), the code of the IPython examples under the [MIT license](https://opensource.org/licenses/MIT). Please attribute the work as follows: *Signals and Systems* by Sascha Spors.
